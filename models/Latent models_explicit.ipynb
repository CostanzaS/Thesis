# %%
# !pip install surprise
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import BaselineOnly
from surprise import SVD
from surprise import NMF
from surprise import accuracy
from surprise.model_selection import KFold
from surprise import Dataset
from surprise.model_selection import train_test_split

# %%
data = Dataset.load_builtin('ml-100k')

# %%
l_r = 0.01

# %%
# method on the given link : http://surpriselib.com and https://surprise.readthedocs.io/en/stable/getting_started.html#use-cross-validation-iterators
svd = SVD(n_factors = n_f, lr_all = l_r, biased = False, reg_bu = 0.02, reg_bi= 0.02,reg_pu =0.06, reg_qi= 0.06)
# Run 5-fold cross-validation and print results.
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9292  0.9260  0.9354  0.9322  0.9311  0.9308  0.0031
# MAE (testset)     0.7353  0.7328  0.7402  0.7372  0.7341  0.7359  0.0026
# Fit time          1.98    1.98    2.00    2.03    2.03    2.00    0.02
# Test time         0.20    0.11    0.20    0.13    0.12    0.15    0.04
# {'fit_time': (1.98038649559021,
#   1.9784150123596191,
#   1.9973011016845703,
#   2.0274481773376465,
#   2.034667491912842),
#  'test_mae': array([0.73529111, 0.73283279, 0.74021866, 0.73722862, 0.73409796]),
#  'test_rmse': array([0.92922169, 0.92598698, 0.93540291, 0.93220934, 0.93113705]),
#  'test_time': (0.20049309730529785,
#   0.1148989200592041,
#   0.2008979320526123,
#   0.12748169898986816,
#   0.11734342575073242)}

# %%
nmf = NMF(n_factors = n_f,lr_bu = l_r, lr_bi=l_r)
# Run 5-fold cross-validation and print results.
cross_validate(nmf, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-ef0e8f6d2b38> in <module>()
#       1 nmf = NMF(n_factors = n_f,lr_bu = l_r, lr_bi=l_r)
#       2 # Run 5-fold cross-validation and print results.
# ----> 3 cross_validate(nmf, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
#
# /usr/local/lib/python3.6/dist-packages/surprise/model_selection/validation.py in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#      99                                            return_train_measures)
#     100                     for (trainset, testset) in cv.split(data))
# --> 101     out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     102
#     103     (test_measures_dicts,
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
# ...

# %%
n_f = 20

# %%
# https://surprise.readthedocs.io/en/stable/prediction_algorithms.html
bsl_options = {'method': 'sgd',
               'learning_rate': l_r,
               'n_factors' : n_f,
               'reg' : 0.02,
               'biased' : False}
sgd = BaselineOnly(bsl_options=bsl_options)

# Run 5-fold cross-validation and print results.
cross_validate(sgd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Evaluating RMSE, MAE of algorithm BaselineOnly on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9389  0.9339  0.9387  0.9444  0.9516  0.9415  0.0061
# MAE (testset)     0.7431  0.7379  0.7420  0.7434  0.7520  0.7437  0.0046
# Fit time          0.55    0.58    0.58    0.57    0.58    0.57    0.01
# Test time         0.19    0.11    0.19    0.11    0.19    0.16    0.04
# {'fit_time': (0.5513925552368164,
#   0.5771970748901367,
#   0.5800948143005371,
#   0.5741631984710693,
#   0.5840973854064941),
#  'test_mae': array([0.7431444 , 0.73788108, 0.74198769, 0.74336477, 0.75201385]),
#  'test_rmse': array([0.93889914, 0.933871  , 0.93869967, 0.94443221, 0.95161307]),
#  'test_time': (0.18761825561523438,
#   0.10744452476501465,
#   0.1857297420501709,
# ...
